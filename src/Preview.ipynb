# %%
import matplotlib.pyplot as plt
from sionna.rt import Scene

# Load the scene
scene = Scene(env_filename=r"C:\Users\snatanzi\Desktop\Causal-XAI\src\factory_scene.xml")

# Open the interactive 3D viewer
scene.preview()
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.31, children=(DirectionalLight(intensity=0.25, position=(0.0, 0.0, …

# %%
# Load the scene
scene = Scene(env_filename="factory_scene.xml")

# Set the active camera
scene.active_sensor = "Camera-Corner"  # or any other camera ID

# Show the preview
scene.preview()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Load the scene
# ----> 2 scene = Scene(env_filename="factory_scene.xml")
#       4 # Set the active camera
#       5 scene.active_sensor = "Camera-Corner"  # or any other camera ID
#
# File C:\Python311\Lib\site-packages\sionna\rt\scene.py:156, in Scene.__init__(self, env_filename, dtype)
#     151     self._scene = mi.load_dict({"type": "scene",
#     152                                 "integrator": {
#     153                                     "type": "path",
#     154                                 }})
#     155 else:
# --> 156     self._scene = mi.load_file(env_filename, parallel=False)
#     157 self._scene_params = mi.traverse(self._scene)
#     159 # Load the cameras
#
# RuntimeError: ​[xml.cpp:1083] Error while loading "factory_scene.xml" (near line 111, col 21): could not instantiate shape plugin of type "ply":
# [xml.cpp:1083]   [PLYMesh] Error while loading PLY file "floor.ply": file not found!
