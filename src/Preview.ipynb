# %%
import matplotlib.pyplot as plt
from sionna.rt import Scene

# Load the scene
scene = Scene(env_filename=r"C:\Users\snatanzi\Desktop\Causal-XAI\src\factory_scene.xml")

# Open the interactive 3D viewer
scene.preview()
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.31, children=(DirectionalLight(intensity=0.25, position=(0.0, 0.0, …

# %%
# Load the scene
scene = Scene(env_filename="factory_scene.xml")

# Set the active camera first
scene.active_sensor = "Camera-Corner"  # or any other camera ID from your XML

# Then preview
scene.preview()
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.31, children=(DirectionalLight(intensity=0.25, position=(0.0, 0.0, …
